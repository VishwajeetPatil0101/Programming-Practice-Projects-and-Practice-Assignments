# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
coffee_production = pd.read_csv("../Data/coffee/total-production.csv").T
coffee_production.columns = coffee_production.iloc[0]
coffee_production = coffee_production.drop("total_production")

coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# 1991                      746.816   79.653  ...  192.532       54.379
# 1992                      900.111   54.291  ...  196.978       39.084
# 1993                     1019.481   70.046  ...  142.066       37.451
# 1994                     1138.659   24.689  ...  248.313       72.738
#
# total_production Sri Lanka  Thailand     Togo Trinidad & Tobago    Uganda  \
# 1990                 95.87   757.017  161.308            14.581  1955.009
# 1991                81.549  1468.936  432.652            17.792  2088.001
# 1992                53.181  1254.945   85.648            14.328  2185.074
# 1993                 53.79  1275.201  194.939            16.079  3141.706
# 1994                42.448  1399.135  176.296            18.435  2392.753
#
# total_production Venezuela  Viet Nam Yemen
# 1990              1122.477  1310.288   0.0
# 1991               940.704  1437.848   0.0
# 1992              1215.298  2340.447   0.0
# 1993              1332.881  3020.216   0.0
# 1994               988.996  3631.609   0.0
#
# [5 rows x 56 columns]

# %% [markdown]
# # Coffee Production Stats
#
# * Create a bar chart of the top 10 coffee producers by total production in 'total-production.csv', sorted from highest to lowest. Change the xticks to two letter country abbreviations.

# %%
coffee_production.tail()
# Out:
# total_production   Angola Bolivia (Plurinational State of)      Brazil  \
# 2014               39.405                          99.8766  53304.7669
# 2015               40.515                          84.2191  52870.5876
# 2016                44.83                          77.9835  56788.1784
# 2017               35.006                          83.8112  52739.8635
# 2018              40.3874                          82.5687  62924.8836
#
# total_production   Burundi   Ecuador   Indonesia Madagascar   Malawi  \
# 2014                247.55  644.0112  10946.2773   501.4544  24.7098
# 2015              274.1017  644.4926  12585.4751   425.2061  21.2015
# 2016              248.7933  644.8845  11541.0266   420.8227   19.516
# 2017              202.1079  623.5744  10852.3153   408.7848  14.4703
# 2018              178.4206  601.0001   9417.5942   396.3764  12.8493
#
# total_production Papua New Guinea Paraguay  ...    Panama Sierra Leone  \
# 2014                     797.5642  20.0725  ...  106.2169      46.4478
# 2015                     711.9818     20.0  ...  127.0784      45.9276
# 2016                    1171.1449  20.0101  ...  120.1902      37.9217
# 2017                     733.9382  20.0024  ...  104.5621      37.9464
# 2018                      930.369  20.0135  ...  130.3021      30.9901
#
# total_production Sri Lanka  Thailand      Togo Trinidad & Tobago    Uganda  \
# 2014               35.7018  844.8871  143.2417           12.0013  3744.477
# 2015               36.1933  761.9808   80.9232           11.7897  3649.567
# 2016               36.7161  537.5435   23.2772           11.7911  4962.158
# 2017               36.7829  638.2325  114.7158           12.0009  4596.813
# 2018               36.0659  482.0069   74.3319           12.3647  4703.964
#
# total_production Venezuela    Viet Nam     Yemen
# 2014              650.3983  26499.8404  178.3814
# 2015              500.1259  28736.5941   156.246
# 2016                 525.0  25540.2932  143.4533
# 2017              571.5128  27887.6555  132.1281
# 2018              525.2602  31174.0742  106.0735
#
# [5 rows x 56 columns]

# %%
coffee_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_production  56 non-null     object
#  1   1990              56 non-null     float64
#  2   1991              56 non-null     float64
#  3   1992              56 non-null     float64
#  4   1993              56 non-null     float64
#  5   1994              56 non-null     float64
#  6   1995              56 non-null     float64
#  7   1996              56 non-null     float64
#  8   1997              56 non-null     float64
#  9   1998              56 non-null     float64
#  10  1999              56 non-null     float64
#  11  2000              56 non-null     float64
#  12  2001              56 non-null     float64
#  13  2002              56 non-null     float64
#  14  2003              56 non-null     float64
#  15  2004              56 non-null     float64
#  16  2005              56 non-null     float64
#  17  2006              56 non-null     float64
#  18  2007              56 non-null     float64
#  19  2008              56 non-null     float64
#  20  2009              56 non-null     float64
#  21  2010              56 non-null     float64
#  22  2011              56 non-null     float64
#  23  2012              56 non-null     float64
#  24  2013              56 non-null     float64
#  25  2014              56 non-null     float64
#  26  2015              56 non-null     float64
#  27  2016              56 non-null     float64
#  28  2017              56 non-null     float64
#  29  2018              56 non-null     float64
# dtypes: float64(29), object(1)
# memory usage: 13.2+ KB

# %%
top10_producers =coffee_production.sum().sort_values(ascending=False).iloc[:10]

top10_producers
# Out:
# total_production
# Brazil       1190965.7353
# Viet Nam      439540.9519
# Colombia      345871.4464
# Indonesia     245116.7707
# Ethiopia      141542.8931
# India          132025.681
# Mexico        126908.2467
# Guatemala     113401.0702
# Honduras      105456.5888
# Uganda          93146.369
# dtype: object

# %%
fig, ax = plt.subplots()
ax.bar(top10_producers.index,top10_producers)
ax.set_xlabel("Countires")
ax.set_ylabel("Total Productions")
ax.set_title("Top 10 coffee producing nations")
ax.set_xticks(top10_producers.index)
plt.xticks(rotation=45);
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# # Top 5 over time
#
# * Create a line chart with the top 5 nations over time. Make sure to include a legend! Consider converting the index to datetime64[ns].

# %%
top5 =coffee_production.loc[:,['Brazil','Viet Nam','Colombia','Indonesia','Ethiopia']]
top5.index=top5.index.astype('datetime64[ns]')

top5.head()
# Out:
# total_production      Brazil  Viet Nam   Colombia Indonesia  Ethiopia
# 1990-01-01        27285.6286  1310.288    14396.0  7441.383  2909.451
# 1991-01-01        27293.4934  1437.848  17980.397  8493.196  2924.664
# 1992-01-01        34603.3542  2340.447  14946.878  5569.478  1825.171
# 1993-01-01        28166.9786  3020.216  11422.422  6743.288  2967.004
# 1994-01-01         28192.047  3631.609    12964.0  5367.878   2762.73

# %%
fig, ax = plt.subplots()
ax.plot(top5)
ax.set_ylabel("production")
ax.legend(top5,bbox_to_anchor=(1,1))
ax.set_title("top coffee producing nations 1992-2018")
plt.show()

# %% [markdown]
# # COMPOSITION OVER TIME
#
# Our client is interested in looking at how Brazil's share of global coffee production has changed over time.
#
# Build a plot that global total production as well as Brazil's contribution to global production over time.

# %%
brazil_vs_others = (coffee_production
                   .assign(rest_of_world= coffee_production
                          .drop('Brazil',axis=1).sum(axis=1))
                   .loc[:,['Brazil','rest_of_world']]
                   .astype({'Brazil':'float64'})
                   )

# %%
brazil_vs_others
# Out:
# total_production      Brazil  rest_of_world
# 1990              27285.6286     65944.4310
# 1991              27293.4934     73973.1910
# 1992              34603.3542     63922.5450
# 1993              28166.9786     63597.6430
# 1994              28192.0470     65121.1470
# 1995              18060.2022     69257.2560
# 1996              29196.7430     74105.8530
# 1997              26148.0040     73713.1950
# 1998              36760.8533     72131.3598
# 1999              47577.8065     83805.9902
# 2000              31310.3530     82456.6197
# 2001              31365.0955     76534.0309
# 2002              48351.6340     74264.1779
# 2003              28873.4093     76633.4004
# 2004              39281.1457     76784.6003
# 2005              32932.9797     78237.6566
# 2006              48431.7338     86958.9091
# 2007              38911.4571     82931.0027
# 2008              51490.5177     83309.1766
# 2009              43976.8120     83997.0027
# 2010              55428.4102     86589.1274
# 2011              48591.8289     93883.5588
# 2012              55418.0012     95866.5109
# 2013              54688.9664     99406.3484
# 2014              53304.7669     96448.2752
# 2015              52870.5876    101117.0573
# 2016              56788.1784    103127.3650
# 2017              52739.8635    105334.3207
# 2018              62924.8836    108011.8541

# %%
fig, ax = plt.subplots()
ax.stackplot(brazil_vs_others.index,
            brazil_vs_others['Brazil'],
            brazil_vs_others['rest_of_world'])

fig.suptitle("Brazil's Share of Global Coffee Production 1990-2018")
ax.set_title("Brazil Increases share of Growing Market")

ax.set_ylabel('production')

ax.set_xticks(brazil_vs_others.index[::4])

ax.legend(brazil_vs_others,loc="upper left");

# %% [markdown]
# ## PRODUCTION RELATIONSHIPS
#
# We want to explore how Brazil compares to its competitors in terms of production. Build a scatterplot  comparing Brazil Vs. VietNam Production and one comparing Brazil to Venezuela.

# %%
brazil_Vietnam = coffee_production.loc[:,['Brazil','Viet Nam']]

brazil_Vietnam
# Out:
# total_production      Brazil    Viet Nam
# 1990              27285.6286    1310.288
# 1991              27293.4934    1437.848
# 1992              34603.3542    2340.447
# 1993              28166.9786    3020.216
# 1994               28192.047    3631.609
# 1995              18060.2022    3970.086
# 1996               29196.743    5752.481
# 1997               26148.004    6978.942
# 1998              36760.8533    7051.722
# 1999              47577.8065  11630.9138
# 2000               31310.353   14841.309
# 2001              31365.0955   13093.244
# 2002               48351.634   11573.935
# 2003              28873.4093   15337.352
# 2004              39281.1457   14370.453
# 2005              32932.9797  13841.8363
# 2006              48431.7338  19339.7501
# 2007              38911.4571  16405.0988
# 2008              51490.5177  18438.1201
# 2009               43976.812  17825.3453
# 2010              55428.4102  19999.9999
# 2011              48591.8289  26499.6111
# 2012              55418.0012  23402.1057
# 2013              54688.9664  27609.7814
# 2014              53304.7669  26499.8404
# 2015              52870.5876  28736.5941
# 2016              56788.1784  25540.2932
# 2017              52739.8635  27887.6555
# 2018              62924.8836  31174.0742

# %%
fig, ax=plt.subplots()
ax.scatter(brazil_Vietnam['Brazil'],
          brazil_Vietnam['Viet Nam'])

ax.set_xlabel("Brazil production")
ax.set_ylabel("Viet nam production")
ax.set_title("Vietnam and Brazil Production Trend Together");

# %%
brazil_Venezuela= coffee_production.loc[:,['Brazil','Venezuela']]

brazil_Venezuela
# Out:
# total_production      Brazil  Venezuela
# 1990              27285.6286   1122.477
# 1991              27293.4934    940.704
# 1992              34603.3542   1215.298
# 1993              28166.9786   1332.881
# 1994               28192.047    988.996
# 1995              18060.2022   1466.554
# 1996               29196.743   1206.162
# 1997               26148.004    951.285
# 1998              36760.8533   1597.279
# 1999              47577.8065   1366.835
# 2000               31310.353   1449.924
# 2001              31365.0955   1264.613
# 2002               48351.634  1483.5896
# 2003              28873.4093  1420.5247
# 2004              39281.1457  1326.5336
# 2005              32932.9797  1506.3009
# 2006              48431.7338  1570.8961
# 2007              38911.4571  1520.4505
# 2008              51490.5177   932.4219
# 2009               43976.812  1213.7061
# 2010              55428.4102  1202.1338
# 2011              48591.8289   902.0717
# 2012              55418.0012   952.4201
# 2013              54688.9664   803.7688
# 2014              53304.7669   650.3983
# 2015              52870.5876   500.1259
# 2016              56788.1784      525.0
# 2017              52739.8635   571.5128
# 2018              62924.8836   525.2602

# %%
fig, ax=plt.subplots()
ax.scatter(brazil_Venezuela['Brazil'],
          brazil_Venezuela['Venezuela'])

ax.set_xlabel("Brazil production")
ax.set_ylabel("Venezuela production")
ax.set_title("Venezuela and Brazil Production Trend Together")
plt.show()

# %% [markdown]
# # COMPOSITION OF COFFEE PRODUCTION
#
# * Create a Pie chart with the top 5 producers, as well as the sum for the rest of countries.
#
# * Finally, create two donut charts, one representing Brazil's share of global production in 1990, and one for Brazil's share in 2018.

# %%
coffee_production["Rest of World"] = coffee_production.drop(["Brazil", 
                                                             "Viet Nam", 
                                                             "Colombia", 
                                                             "Indonesia",
                                                             "Ethiopia",], axis=1).sum(axis=1)
coffee_production_top5_2018 = coffee_production.loc['2018', ["Brazil", 
                                                             "Viet Nam", 
                                                             "Colombia", 
                                                             "Indonesia",
                                                             "Ethiopia",
                                                             "Rest of World"
                                                            ]
                                                   ]

coffee_production_top5_2018
# Out:
# total_production
# Brazil           62924.8836
# Viet Nam         31174.0742
# Colombia          13857.962
# Indonesia         9417.5942
# Ethiopia          7776.2234
# Rest of World    91572.0006
# Name: 2018, dtype: object

# %%
fig, ax=plt.subplots()
ax.pie(coffee_production_top5_2018,startangle=90,labels=coffee_production_top5_2018.index,autopct="%.0f%%")
ax.set_title("share of global coffee production 2018")
plt.show()

# %%
brazil_vs_others = (coffee_production
                    .assign(rest_of_world = coffee_production
                            .drop("Brazil", axis=1).sum(axis=1))
                    .loc[:, ["Brazil", "rest_of_world"]]
                    .astype({"Brazil": "float64"})
                   )


brazil_vs_others
# Out:
# total_production      Brazil  rest_of_world
# 1990              27285.6286    145719.0490
# 1991              27293.4934    160247.3630
# 1992              34603.3542    142403.6870
# 1993              28166.9786    142487.0690
# 1994              28192.0470    145911.0070
# 1995              18060.2022    158478.0580
# 1996              29196.7430    165998.8450
# 1997              26148.0040    161581.4250
# 1998              36760.8533    160107.3514
# 1999              47577.8065    188449.4168
# 2000              31310.3530    176443.7597
# 2001              31365.0955    157759.8467
# 2002              48351.6340    154570.0277
# 2003              28873.4093    155524.6632
# 2004              39281.1457    153256.5389
# 2005              32932.9797    155247.8070
# 2006              48431.7338    171802.0145
# 2007              38911.4571    163466.1451
# 2008              51490.5177    166600.0420
# 2009              43976.8120    163523.4075
# 2010              55428.4102    169464.2704
# 2011              48591.8289    185970.1206
# 2012              55418.0012    182335.3419
# 2013              54688.9664    180094.5556
# 2014              53304.7669    174635.3796
# 2015              52870.5876    179261.5199
# 2016              56788.1784    191356.7176
# 2017              52739.8635    195967.4091
# 2018              62924.8836    199583.8547

# %%
fig, ax=plt.subplots()
ax.pie(
    brazil_vs_others.iloc[0].sort_values(ascending=False),
    startangle=90,
    labels = ["", ""],
    pctdistance=.85,
    colors=["White", "Blue"]
)

hole= plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(hole)


plt.text(
    0, 
    0, 
    f"{round((brazil_vs_others.loc['1990', 'Brazil'] / brazil_vs_others.loc['1990'].sum()*100))}%", 
    ha='center', 
    va='center', 
    fontsize=42
)

ax.set_title("Brazil share of global production 1990");

# %%
fig, ax=plt.subplots()
ax.pie(
    brazil_vs_others.iloc[0].sort_values(ascending=False),
    startangle=90,
    labels = ["", ""],
    pctdistance=.85,
    colors=["White", "Blue"]
)

hole= plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(hole)


plt.text(
    0, 
    0, 
    f"{round((brazil_vs_others.loc['2018', 'Brazil'] / brazil_vs_others.loc['2018'].sum()*100))}%", 
    ha='center', 
    va='center', 
    fontsize=42
)

ax.set_title("Brazil share of global production 2018");

# %% [markdown]
# # Coffee Consumption Vs. Prices
#
# Compare coffee prices with coffee consumption in the following countries.
#
# Is there a relationship between coffee consumption and the price these countries pay?
#
# Plot a dual axis bar chart of price vs consumption totals for these countries.

# %%
consumption = pd.read_csv("../Data/coffee/imports.csv").set_index("imports").mean(axis=1)

consumption.name = "imports"

consumption.head()
# Out:
# imports
#    Austria               1551.083333
#    Belgium               4639.533333
#    Belgium/Luxembourg    2329.444444
#    Bulgaria               397.250000
#    Croatia                349.136364
# Name: imports, dtype: float64

# %%
prices = pd.read_csv("../Data/coffee/retail-prices.csv").set_index("retail_prices").mean(axis=1)


prices.head()
# Out:
# retail_prices
#    Austria    11.571135
#    Cyprus     10.437695
#    Denmark    10.494025
#    Finland     7.211692
#    France      6.850879
# dtype: float64

# %%
price_cons = (pd.DataFrame(prices)
              .merge(consumption, 
                    left_on=prices.index, 
                    right_on=consumption.index, 
                    how="inner"
            )
           .sort_values(["imports"], ascending=False)
)

price_cons.columns= ["country", "Price", "Imports"]


price_cons["country"] = price_cons["country"].str.strip(" ")

price_cons
# Out:
#         country      Price       Imports
# 5       Germany   9.515110  16357.666667
# 11        Japan  21.472939   6862.275235
# 6         Italy  14.199589   6696.958333
# 4        France   6.850879   6512.458333
# 9         Spain   8.029992   4046.291667
# 7   Netherlands   8.931263   2928.125000
# 10       Sweden   8.054350   1620.625000
# 0       Austria  11.571135   1551.083333
# 3       Finland   7.211692   1157.541667
# 2       Denmark  10.494025    991.791667
# 8      Portugal  10.921063    810.791667
# 12       Norway   9.409302    739.770359
# 1        Cyprus  10.437695     63.791667

# %%
fig, ax=plt.subplots(figsize=(10,8))
width=.35
x=np.arange(13)
ax.bar( x-width/2,
      price_cons["Imports"],
      width=width,
      label="Consumption")
ax.set_ylabel("Consumption")

ax2=ax.twinx()

ax2.bar(x+width/2,
      price_cons["Price"],
      width=width,
      label="Price",
      color="orange"
      )
ax2.set_ylabel("Average price paid per bags")

ax.set_xticks(x)
ax.set_xticklabels(price_cons["country"],fontsize=8)


ax.set_title("Price vs consumption of selected importing nations")
fig.legend(bbox_to_anchor=(.9,.88))

plt.show()
